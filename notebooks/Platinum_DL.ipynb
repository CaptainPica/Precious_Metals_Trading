# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pandas import read_csv
from sklearn.preprocessing import LabelEncoder
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from numpy import concatenate
from pandas import DataFrame
from math import sqrt
# Out:
# Using TensorFlow backend.

# %%
# The path to our CSV file
file = "../data/csv/Platinum_Data.csv"
df = pd.read_csv(file)
df.head()
postfitdf = df

# %%
#new = old.filter(['A','B','D'], axis=1)

df1 = df.filter(['Date','Platinum_Settle', 'Open Interest', 'Money Manager Shorts', 'Money Manager Longs', 'Producer/Merchant/Processor/User Longs', 'Producer/Merchant/Processor/User Shorts'], axis=1)

# %%
#raw_data['Mycol'] =  pd.to_datetime(raw_data['Mycol'], format='%d%b%Y:%H:%M:%S.%f')

df1['Date'] = pd.to_datetime(df1['Date'])
df1.set_index('Date', inplace = True)

# %%
df1.head()
# Out:
#             Platinum_Settle  Open Interest  Money Manager Shorts  \
# Date
# 2006-06-13          1180.34         8616.0                3164.0
# 2006-06-20          1150.14         7380.0                2018.0
# 2006-06-27          1181.30         8093.0                1908.0
# 2006-07-03          1210.20         7338.0                1178.0
# 2006-07-11          1246.32         8213.0                 833.0
#
#             Money Manager Longs  Producer/Merchant/Processor/User Longs  \
# Date
# 2006-06-13               3257.0                                  1297.0
# 2006-06-20               2964.0                                   932.0
# 2006-06-27               3036.0                                  1046.0
# 2006-07-03               3058.0                                   656.0
# 2006-07-11               3897.0                                   423.0
#
#             Producer/Merchant/Processor/User Shorts
# Date
# 2006-06-13                                   3059.0
# 2006-06-20                                   3319.0
# 2006-06-27                                   3622.0
# 2006-07-03                                   3905.0
# 2006-07-11                                   4336.0

# %%
df1.corr()
# Out:
#                                          Platinum_Settle  Open Interest  \
# Platinum_Settle                                 1.000000      -0.433142
# Open Interest                                  -0.433142       1.000000
# Money Manager Shorts                           -0.640621       0.708710
# Money Manager Longs                            -0.097957       0.862749
# Producer/Merchant/Processor/User Longs         -0.625213       0.828912
# Producer/Merchant/Processor/User Shorts        -0.199838       0.882624
#
#                                          Money Manager Shorts  \
# Platinum_Settle                                     -0.640621
# Open Interest                                        0.708710
# Money Manager Shorts                                 1.000000
# Money Manager Longs                                  0.318834
# Producer/Merchant/Processor/User Longs               0.795919
# Producer/Merchant/Processor/User Shorts              0.338089
#
#                                          Money Manager Longs  \
# Platinum_Settle                                    -0.097957
# Open Interest                                       0.862749
# Money Manager Shorts                                0.318834
# Money Manager Longs                                 1.000000
# Producer/Merchant/Processor/User Longs              0.572478
# Producer/Merchant/Processor/User Shorts             0.930786
#
#                                          Producer/Merchant/Processor/User Longs  \
# Platinum_Settle                                                       -0.625213
# Open Interest                                                          0.828912
# Money Manager Shorts                                                   0.795919
# Money Manager Longs                                                    0.572478
# Producer/Merchant/Processor/User Longs                                 1.000000
# Producer/Merchant/Processor/User Shorts                                0.623251
#
#                                          Producer/Merchant/Processor/User Shorts
# Platinum_Settle                                                        -0.199838
# Open Interest                                                           0.882624
# Money Manager Shorts                                                    0.338089
# Money Manager Longs                                                     0.930786
# Producer/Merchant/Processor/User Longs                                  0.623251
# Producer/Merchant/Processor/User Shorts                                 1.000000

# %%
from matplotlib import pyplot
# load dataset
#dataset = read_csv('pollution.csv', header=0, index_col=0)
values
- acc: 0.0019 - val_loss: 0.0121 - val_acc: 0.0059
# Epoch 103/125
#  - 0s - loss: 0.0215 - acc: 0.0019 - val_loss: 0.0136 - val_acc: 0.0059
# Epoch 104/125
#  - 0s - loss: 0.0212 - acc: 0.0019 - val_loss: 0.0121 - val_acc: 0.0059
# Epoch 105/125
#  - 0s - loss: 0.0212 - acc: 0.0019 - val_loss: 0.0126 - val_acc: 0.0059
# Epoch 106/125
#  - 0s - loss: 0.0211 - acc: 0.0019 - val_loss: 0.0119 - val_acc: 0.0059
# Epoch 107/125
#  - 0s - loss: 0.0214 - acc: 0.0019 - val_loss: 0.0132 - val_acc: 0.0059
# Epoch 108/125
#  - 0s - loss: 0.0213 - acc: 0.0019 - val_loss: 0.0120 - val_acc: 0.0059
# Epoch 109/125
#  - 0s - loss: 0.0212 - acc: 0.0019 - val_loss: 0.0126 - val_acc: 0.0059
# Epoch 110/125
#  - 0s - loss: 0.0211 - acc: 0.0019 - val_loss: 0.0123 - val_acc: 0.0059
# Epoch 111/125
#  - 0s - loss: 0.0210 - acc: 0.0019 - val_loss: 0.0121 - val_acc: 0.0059
# Epoch 112/125
#  - 0s - loss: 0.0210 - acc: 0.0019 - val_loss: 0.0121 - val_acc: 0.0059
# Epoch 113/125
#  - 0s - loss: 0.0210 - acc: 0.0019 - val_loss: 0.0125 - val_acc: 0.0059
# Epoch 114/125
#  - 0s - loss: 0.0210 - acc: 0.0019 - val_loss: 0.0119 - val_acc: 0.0059
# Epoch 115/125
#  - 0s - loss: 0.0211 - acc: 0.0019 - val_loss: 0.0130 - val_acc: 0.0059
# Epoch 116/125
#  - 0s - loss: 0.0210 - acc: 0.0019 - val_loss: 0.0121 - val_acc: 0.0059
# Epoch 117/125
#  - 0s - loss: 0.0210 - acc: 0.0019 - val_loss: 0.0120 - val_acc: 0.0059
# Epoch 118/125
#  - 0s - loss: 0.0210 - acc: 0.0019 - val_loss: 0.0123 - val_acc: 0.0059
# Epoch 119/125
#  - 0s - loss: 0.0209 - acc: 0.0019 - val_loss: 0.0121 - val_acc: 0.0059
# Epoch 120/125
#  - 0s - loss: 0.0209 - acc: 0.0019 - val_loss: 0.0120 - val_acc: 0.0059
# Epoch 121/125
#  - 0s - loss: 0.0210 - acc: 0.0019 - val_loss: 0.0122 - val_acc: 0.0059
# Epoch 122/125
#  - 0s - loss: 0.0210 - acc: 0.0019 - val_loss: 0.0128 - val_acc: 0.0059
# Epoch 123/125
#  - 0s - loss: 0.0210 - acc: 0.0019 - val_loss: 0.0117 - val_acc: 0.0059
# Epoch 124/125
#  - 0s - loss: 0.0211 - acc: 0.0019 - val_loss: 0.0129 - val_acc: 0.0059
# Epoch 125/125
#  - 0s - loss: 0.0209 - acc: 0.0019 - val_loss: 0.0119 - val_acc: 0.0059

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 50)                11400
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 11,451
# Trainable params: 11,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 21.771

# %%
pyplot.plot(inv_yhat, label="predicted value")
pyplot.plot(inv_y, label="actual value")
pyplot.legend()
pyplot.show()

# %%
pyplot.plot(inv_yhat[-50:], label="predicted value")
pyplot.plot(inv_y[-50:], label="actual value")
pyplot.legend()
pyplot.show()

# %%
inv_yhat[len(inv_yhat)-2]
# Out:
# 820.605

# %%
inv_y[len(inv_y)-1]
# Out:
# 846.88

# %%
# The path to our CSV file
file2 = "../data/csv/PlatinumPrices.csv"
df3 = pd.read_csv(file2)
df4 = df3.filter(['Date','Settle'])
df4['Date'] = pd.to_datetime(df4['Date'])
RelVal = inv_yhat.tolist()
RelVal.reverse()
WklyDate = postfitdf['Date'].iloc[::-1].tolist()
z = {'Date': WklyDate, 'Relative Value': RelVal}
df5 = pd.concat([pd.Series(v, name=k) for k, v in z.items()], axis=1)
df5['Date'] = pd.to_datetime(df5['Date'])

PredictDF = pd.merge(df4, df5, on='Date', how='outer')
FinalPredict_DF = PredictDF.head(len(test_y))
FinalPredict_DF2 = FinalPredict_DF.fillna(method='bfill')

# %%
fig = pyplot.figure()
host = fig.add_subplot(111)
host.set_ylabel('Price')

line1, = host.plot(FinalPredict_DF2['Date'], FinalPredict_DF2['Settle'], color='black', linestyle='dotted', linewidth=2)
line2, = host.plot(FinalPredict_DF2['Date'], FinalPredict_DF2['Relative Value'], 'go', markersize=4)
host.legend([line1, line2], ['Settle', 'Relative Value'])

host.xaxis_date()
pyplot.show()

# %%
FinalPredict_DF2.head()
# Out:
#         Date  Settle  Relative Value
# 0 2019-07-26   862.7      835.538757
# 1 2019-07-25   868.4      835.538757
# 2 2019-07-24   875.2      835.538757
# 3 2019-07-23   855.8      835.538757
# 4 2019-07-22   847.3      820.604980

# %%
for i in range(len(FinalPredict_DF2.index)-3):
    FinalPredict_DF2.at[i,"Relative Value"] = FinalPredict_DF2["Relative Value"][i+3]
FinalPredict_DF2 = FinalPredict_DF2.iloc[:len(FinalPredict_DF2.index)-3]

FinalPredict_DF2.head(20)
# Out:
#          Date  Settle  Relative Value
# 0  2019-07-26   862.7      835.538757
# 1  2019-07-25   868.4      820.604980
# 2  2019-07-24   875.2      820.604980
# 3  2019-07-23   855.8      820.604980
# 4  2019-07-22   847.3      820.604980
# 5  2019-07-19   845.9      820.604980
# 6  2019-07-18   843.7      826.323242
# 7  2019-07-17   841.7      826.323242
# 8  2019-07-16   841.5      826.323242
# 9  2019-07-15   839.5      826.323242
# 10 2019-07-12   828.4      826.323242
# 11 2019-07-11   825.0      805.035645
# 12 2019-07-10   824.1      805.035645
# 13 2019-07-09   809.1      805.035645
# 14 2019-07-08   814.3      805.035645
# 15 2019-07-05   805.2      797.127319
# 16 2019-07-03   837.2      797.127319
# 17 2019-07-02   827.2      797.127319
# 18 2019-07-01   831.1      797.127319
# 19 2019-06-28   835.5      797.127319

# %%
only_fridays = [i for i in range(0,len(FinalPredict_DF2.index)+1,5)]
weekly = FinalPredict_DF2.iloc[only_fridays]
weekly.head()
# Out:
#          Date  Settle  Relative Value
# 0  2019-07-26   862.7      835.538757
# 5  2019-07-19   845.9      820.604980
# 10 2019-07-12   828.4      826.323242
# 15 2019-07-05   805.2      797.127319
# 20 2019-06-27   812.6      803.137756

# %%
weekly['Settle Delta'] = weekly['Settle'].diff(+1)
weekly['Settle Delta'] = weekly['Settle Delta'].apply(lambda x:x*-1)
weekly['Rel Val Delta'] = weekly['Relative Value'].diff(-1)

Signal = np.sign(weekly['Rel Val Delta'])
weekly2 = pd.concat([weekly, pd.DataFrame(Signal)], axis=1)
weekly2.columns = ['Date', 'Settle', 'Relative Value', 'Settle Delta', 'Rel Val Delta', 'Signal']

weekly2['Profit'] = weekly2['Settle Delta']*weekly2['Signal']
weekly2['EC'] = weekly2.Profit[::-1].cumsum()
ax = weekly2['EC'].plot(title='Platinum RNN Model Equity Curve')
ax.invert_xaxis()
# Out:
# C:\Users\omar.aziz\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\omar.aziz\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\omar.aziz\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\omar.aziz\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in sign
#   """
